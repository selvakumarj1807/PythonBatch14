# %%
import studentModule

# %%
print(studentModule.collegeName, ' - ', studentModule.website)
# Out:
# ABC College of Engineering  -  www.abccollege.edu

# %%
studentModule.studentDetails('Priya', 101)
# Out:
# Student Name: Priya
# Roll Number: 101
# College Name: ABC College of Engineering
# Website: www.abccollege.edu
