# %% [markdown]
# # Python Basics

# %%
print('Hello Python!...')
# Out:
# Hello Python!...

# %% [markdown]
# # Single Line & Multi Line Comment

# %%
# Single Line Comment

'''
Multiple 
line 
comment
'''

print('Hello Python!...')
# Out:
# Hello Python!...
