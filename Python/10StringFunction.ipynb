# %% [markdown]
# # String Function

# %%
msg = 'hI wELcome PyTHoN'

print(msg)
# Out:
# hI wELcome PyTHoN

# %%
print(msg.upper())

lowerCase = msg.lower()

print(lowerCase)

print(msg.title())

print(msg.capitalize())
# Out:
# HI WELCOME PYTHON
# hi welcome python
# Hi Welcome Python
# Hi welcome python

# %% [markdown]
# # ToDay Task
#
# To write the Python Code for Below OutPuts
#
# details = [10, 'PRIYA', 'priya18@gmail.com', 9500912258, 875463]
#
# # OutPut 01
#
# Enter your name : priya
#
# Hi Priya!.. Welcome Python
#
# # OutPut 02
#
# Enter your name : dharshini
#
# Dharshini is not in your Class
#
# # Output 03
#
# Hi Priya18!...
#
# # Output 04
#
# 9500912258 - is Valid Mobile Number
#
# 875463 - is InValid Mobile Number
